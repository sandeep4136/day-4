# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.1.4

# %%
import numpy as np
a=np.array([1,2,3,4])
b=pd.Series(a)
b
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
df=pd.DataFrame(a)
df['index']=b.index
df
# Out:
#    0  index
# 0  1      0
# 1  2      1
# 2  3      2
# 3  4      3

# %%
import seaborn as sbn
sbn.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-8f8733c25ee9> in <module>
# ----> 1 import seaborn as sbn
#       2 sbn.get_dataset_names()
#
# ModuleNotFoundError: No module named 'seaborn'
